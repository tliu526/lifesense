# %% [markdown]
#  # LifeSense EMA Missingness Wave 1

# %%
# imports and constants
# %matplotlib inline
import json
import pickle

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import seaborn as sns

from IPython.display import display, HTML
import ipywidgets as widgets

# %%
# Code hider, source: http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/
from IPython.display import HTML

HTML('''
<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# load ids and data

with open("data_pull/ids/wave1_ids.txt", "r") as internal_f:
    wave1_ids = [line.strip() for  line in internal_f.readlines()]

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### Morning EMAs

# %%
morn_ema_df = pd.DataFrame()
all_ids = wave1_ids

for pid in all_ids:
    morn_df = pd.read_pickle("data_pull_ema_issues/morning_ema/{}.df".format(pid))
    morn_ema_df = morn_ema_df.append(morn_df, sort=True)

# %%
morn_ema_df['timestamp'] = morn_ema_df['timestamp'].astype(int)
morn_ema_df['timezone-offset'] = morn_ema_df['timezone-offset'].astype(int)
morn_ema_df['sleep-quality'] = morn_ema_df['sleep-quality'].astype(int)

morn_ema_df['adj_ts'] = morn_ema_df['timestamp'] + morn_ema_df['timezone-offset']
morn_ema_df['date'] = pd.to_datetime(morn_ema_df['adj_ts'], unit='s').dt.floor('d')
morn_ema_df['pid'] = 'p' + morn_ema_df['source']

# %%
fig, ax = plt.subplots()
morn_ema_df['date'].hist(bins=70, ax=ax)
plt.xticks(rotation='45', ha='right')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=7)) 
ax.set_title("Distribution of Morning EMAs for Wave 1")
plt.ylabel("frequency")
fig.show()

# %% [markdown]
# ### Morning PHQ8

# %%
morn_phq8_df = pd.DataFrame()
all_ids = wave1_ids

for pid in all_ids:
    morn_df = pd.read_pickle("data_pull_ema_issues/morning_phq8/{}.df".format(pid))
    morn_phq8_df = morn_phq8_df.append(morn_df, sort=True)

# %%
morn_phq8_df['timestamp'] = morn_phq8_df['timestamp'].astype(int)
morn_phq8_df['timezone-offset'] = morn_phq8_df['timezone-offset'].astype(int)
morn_phq8_df['sleep-quality'] = morn_phq8_df['sleep-quality'].astype(int)

morn_phq8_df['adj_ts'] = morn_phq8_df['timestamp'] + morn_phq8_df['timezone-offset']
morn_phq8_df['date'] = pd.to_datetime(morn_phq8_df['adj_ts'], unit='s').dt.floor('d')
morn_phq8_df['pid'] = 'p' + morn_phq8_df['source']

# %%
fig, ax = plt.subplots()
morn_phq8_df['date'].hist(bins=70, ax=ax)
plt.xticks(rotation='45', ha='right')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=7)) 
ax.set_title("Distribution of Morning PHQ8 for Wave 1")
plt.ylabel("frequency")
fig.show()

# %% [markdown]
# ### Evening EMAs

# %%
even_ema_df = pd.DataFrame()

for pid in all_ids:
    even_df = pd.read_pickle("data_pull_ema_issues/evening_ema/{}.df".format(pid))
    even_ema_df = even_ema_df.append(even_df, sort=True)

# %% [markdown]
# #### "For yesterday" readings

# %%
display(even_ema_df['for_yesterday'].value_counts())
# Out:
# False    4381
# True      506
# Name: for_yesterday, dtype: int64

# %%
even_ema_df['timestamp'] = even_ema_df['timestamp'].astype(int)
even_ema_df['timezone-offset'] = even_ema_df['timezone-offset'].astype(int)

even_ema_df['adj_ts'] = even_ema_df['timestamp'] + even_ema_df['timezone-offset']
even_ema_df['date'] = pd.to_datetime(even_ema_df['adj_ts'], unit='s').dt.floor('d')
even_ema_df['pid'] = 'p' + even_ema_df['source']

# %%
# adjust for yesterday surveys
even_ema_df['for_yesterday'] = even_ema_df['for_yesterday'].fillna(0)
even_ema_df['for_yesterday'] = even_ema_df['for_yesterday'].astype(int)
even_ema_df['adj_date'] = even_ema_df['date'] - pd.to_timedelta(even_ema_df['for_yesterday'], unit='D')

# %%
fig, ax = plt.subplots()
even_ema_df['adj_date'].hist(bins=71, ax=ax)
plt.xticks(rotation='45', ha='right')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=7)) 
ax.set_title("Distribution of Evening EMAs for Wave 1")
plt.ylabel("frequency")
fig.show()

# %%
even_ema_df['time'] = pd.to_datetime(even_ema_df['adj_ts'], unit='s').dt.round('H').dt.hour

# %%
even_ema_df.loc[even_ema_df['for_yesterday'] == 1]['time'].hist(bins=24)
plt.xlabel("Hour")
plt.ylabel("Frequency")
plt.ylim(0,250)
plt.title("Distribution of For Yesterday Evening EMA survey completion time")
plt.show()

# %%
even_ema_df.loc[even_ema_df['for_yesterday'] == 0]['time'].hist(bins=24)
plt.xlabel("Hour")
plt.ylabel("Frequency")
plt.title("Distribution of For Today Evening EMA survey completion time")
plt.show()

# %% [markdown]
# ### Evening PHQ8

# %%
even_phq8_df = pd.DataFrame()
all_ids = wave1_ids

for pid in all_ids:
    even_df = pd.read_pickle("data_pull_ema_issues/evening_phq8/{}.df".format(pid))
    even_phq8_df = even_phq8_df.append(even_df, sort=True)

# %%
even_phq8_df['timestamp'] = even_phq8_df['timestamp'].astype(int)
even_phq8_df['timezone-offset'] = even_phq8_df['timezone-offset'].astype(int)
#even_phq8_df['sleep-quality'] = even_phq8_df['sleep-quality'].astype(int)

even_phq8_df['adj_ts'] = even_phq8_df['timestamp'] + even_phq8_df['timezone-offset']
even_phq8_df['date'] = pd.to_datetime(even_phq8_df['adj_ts'], unit='s').dt.floor('d')
even_phq8_df['pid'] = 'p' + even_phq8_df['source']

# %%
fig, ax = plt.subplots()
even_phq8_df['date'].hist(bins=71, ax=ax)
plt.xticks(rotation='45', ha='right')
ax.xaxis.set_major_locator(mdates.DayLocator(interval=7)) 
ax.set_title("Distribution of evening PHQ8 for Wave 1")
plt.ylabel("frequency")
fig.show()

# %% [markdown]
# ## Completed EMA Statistics

# %%
def get_completion_stats(df, start_date, end_date):
    """
    Returns the count as well as the unique number of respondents in each date range
    """
    sel_df = df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)]
    count = sel_df.shape[0]
    n_unique = sel_df['pid'].unique().shape[0]
    
    return count, n_unique

# %%
dates = [
    ('07-30-2019', '08-05-2019'),
    ('08-20-2019', '08-26-2019'),
    ('09-10-2019', '09-16-2019'),
    ('10-01-2019', '10-07-2019'),
]

dfs = [
    (morn_ema_df, 'morn_ema'),
    (even_ema_df, 'even_ema'),
    (morn_phq8_df, 'morn_ema_phq8'),
    (even_phq8_df, 'even_ema_phq8')
]

# %%
ema_count_df = pd.DataFrame(columns=dates)

ema_count_idx = []
for _, name in dfs:
    ema_count_idx.append(name + '_count')
    ema_count_idx.append(name + '_n_unique')
    

ema_count_df['idx'] = ema_count_idx
ema_count_df = ema_count_df.set_index('idx')

for date_tup in dates:
    start_date = date_tup[0]
    end_date = date_tup[1]
    col = []
    for df, name in dfs:
        count, n_unique = get_completion_stats(df, start_date, end_date)
        col.append(count)
        col.append(n_unique)
        
    ema_count_df[date_tup] = col

# %%
ema_count_df
# Out:
#                         (07-30-2019, 08-05-2019)  (08-20-2019, 08-26-2019)  \
# idx
# morn_ema_count                              1398                      1027
# morn_ema_n_unique                            258                       231
# even_ema_count                              1381                       929
# even_ema_n_unique                            254                       233
# morn_ema_phq8_count                          220                       122
# morn_ema_phq8_n_unique                       212                       122
# even_ema_phq8_count                          205                       161
# even_ema_phq8_n_unique                       205                       161
#
#                         (09-10-2019, 09-16-2019)  (10-01-2019, 10-07-2019)
# idx
# morn_ema_count                              1336                      1320
# morn_ema_n_unique                            247                       246
# even_ema_count                              1293                      1281
# even_ema_n_unique                            246                       246
# morn_ema_phq8_count                          179                       232
# morn_ema_phq8_n_unique                       179                       232
# even_ema_phq8_count                          182                       194
# even_ema_phq8_n_unique                       182                       191

# %% [markdown]
# ## Total PHQ Completions

# %% [markdown]
# ### Morning PHQ

# %%
pd.set_option("display.max_rows", 300)
morn_phq8_df['source'].value_counts().to_frame()
# Out:
#           source
# 53236058       6
# 73916801       5
# 46484562       5
# 18583649       5
# 28458341       5
# 39548248       5
# 77579838       4
# 55979795       4
# 31477083       4
# 48315222       4
# 51419094       4
# 69452375       4
# 84469352       4
# 04918121       4
# 58780031       4
# 86756971       4
# 39854689       4
# 01254121       4
# 46175798       4
# 27330785       4
# 04133537       4
# 90638927       4
# 15565415       4
# 68744652       4
# 66873010       4
# 43589028       4
# 54461187       4
# 13250317       4
# 65143770       4
# 20206315       4
# 62808613       4
# 11927637       4
# 02970060       4
# 55313474       4
# 01766910       4
# 98250113       4
# 79316475       4
# 53097921       4
# 09269616       4
# 22656406       4
# 67597747       4
# 40932643       4
# 51735262       4
# 31456993       4
# 74575289       4
# 53808826       4
# 57973631       4
# 89434074       4
# 91048552       4
# 10099555       4
# 89057862       4
# 09611865       4
# 01495950       4
# 59764431       4
# 51612397       4
# 81729157       4
# 82727218       4
# 06638392       4
# 80657933       4
# 74589634       4
# 74133461       4
# 14113160       4
# 57473014       4
# 06400675       4
# 54004910       4
# 74371880       4
# 39725031       4
# 76432041       4
# 20706360       4
# 26957252       4
# 21594071       4
# 23066392       4
# 62463869       3
# 26080346       3
# 02144163       3
# 81720300       3
# 54004910       3
# 55463070       3
# 90934495       3
# 12616311       3
# 03939827       3
# 58081753       3
# 16777771       3
# 80504454       3
# 62599280       3
# 46175798       3
# 45517860       3
# 18583649       3
# 11770862       3
# 61131074       3
# 81249330       3
# 79439002       3
# 13051775       3
# 65149091       3
# 23388083       3
# 71676393       3
# 01495950       3
# 73142171       3
# 47363974       3
# 79510141       3
# 18740846       3
# 03578019       3
# 30501084       3
# 42215399       3
# 79819446       3
# 27330785       3
# 42871706       2
# 01225297       2
# 84877086       2
# 83085276       2
# 04918121       2
# 22498610       2
# 09489685       2
# 36969413       2
# 64292248       2
# 99127649       2
# 75348018       2
# 28244292       2
# 44655272       2
# 31477083       2
# 68756107       2
# 37168430       2
# 06638392       2
# 83275234       2
# 07974290       2
# 53808826       2
# 86283726       1
# 65696941       1
# 70035688       1
# 14196469       1
# 53874087       1
# 47688944       1
# 70027963       1
# 28939704       1
# 52982527       1
# 45761494       1
# 93627939       1
# 28021601       1
# 76854891       1
# 75696701       1
# 59222410       1
# 43093019       1
# 21150752       1
# 99050875       1
# 29584096       1
# 80700486       1
# 67900112       1
# 70483015       1

# %% [markdown]
# ## Duplicates

# %% [markdown]
# ### Morning EMA

# %%
morn_ema_sorted = morn_ema_df.sort_values(by=['pid', 'date', 'adj_ts'])

# %%
morn_ema_sorted['adj_ts_next'] = morn_ema_sorted['adj_ts'].shift(-1)

# %%
morn_ema_sorted['ts_diff'] = morn_ema_sorted['adj_ts_next'] - morn_ema_sorted['adj_ts']

# %%
morn_ema_sorted.loc[(morn_ema_sorted['ts_diff'] > 0) & (morn_ema_sorted['ts_diff'] < 60)]
# Out:
#    bed-time data_source encrypted_transmission for_yesterday  \
# 4     20:20       wave1                   True         False
# 18    21:00       wave1                   True         False
# 9     22:00       wave1                   True         False
# 2     23:15       wave1                   True         False
#
#                                             generator generator-id mood  \
# 4   morning_ema: LifeSense/27 Passive Data Kit/1.0...  morning_ema    5
# 18  morning_ema: LifeSense/35 Passive Data Kit/1.0...  morning_ema    5
# 9   morning_ema: LifeSense/35 Passive Data Kit/1.0...  morning_ema    6
# 2   morning_ema: LifeSense/35 Passive Data Kit/1.0...  morning_ema    8
#
#           pid rise-time  sleep-quality  ...    source   timestamp  \
# 4   p06400675     13:01              4  ...  06400675  1564942413
# 18  p83275234      6:00              5  ...  83275234  1570457689
# 9   p91048552      6:50              6  ...  91048552  1568289868
# 2   p99050875      7:15              8  ...  99050875  1570395152
#
#            timezone timezone-offset  wake-time         workday      adj_ts  \
# 4   America/Chicago          -18000      13:01  is-not-workday  1564924413
# 18  America/Chicago          -18000       5:30      is-workday  1570439689
# 9   America/Chicago          -18000       6:15      is-workday  1568271868
# 2   America/Chicago          -18000       7:10      is-workday  1570377152
#
#          date   adj_ts_next  ts_diff
# 4  2019-08-04  1.564924e+09     55.0
# 18 2019-10-07  1.570440e+09     41.0
# 9  2019-09-12  1.568272e+09     21.0
# 2  2019-10-06  1.570377e+09     42.0
#
# [4 rows x 21 columns]

# %%
morn_ema_sorted.loc[morn_ema_sorted['date'] == '2019-08-04'].shape
# Out:
# (240, 21)

# %% [markdown]
# ### evening EMA

# %%
even_ema_sorted = even_ema_df.sort_values(by=['pid', 'date', 'adj_ts'])

# %%
even_ema_sorted['adj_ts_next'] = even_ema_sorted['adj_ts'].shift(-1)

# %%
even_ema_sorted['ts_diff'] = even_ema_sorted['adj_ts_next'] - even_ema_sorted['adj_ts']

# %%
even_ema_sorted.loc[(even_ema_sorted['ts_diff'] > 0) & (even_ema_sorted['ts_diff'] < 60)]
# Out:
#    cluster_distance cluster_min_points data_source encrypted_transmission  \
# 18               56                  5       wave1                   True
# 1               100                  3       wave1                   True
# 3               100                  3       wave1                   True
# 9               100                  3       wave1                   True
# 16              100                  3       wave1                   True
# 4               100                  3       wave1                   True
# 13              200                  2       wave1                   True
# 7                75                  4       wave1                   True
# 15              100                  3       wave1                   True
# 16              100                  3       wave1                   True
# 5               100                  3       wave1                   True
# 13              100                  3       wave1                   True
# 9                93                  3       wave1                   True
# 10               93                  3       wave1                   True
# 4               100                  3       wave1                   True
# 1               100                  3       wave1                   True
# 1               100                  3       wave1                   True
# 5               100                  3       wave1                   True
#
#     for_yesterday                                          generator  \
# 18              0  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 1               0  evening_ema: LifeSense/27 Passive Data Kit/1.0...
# 3               1  evening_ema: LifeSense/27 Passive Data Kit/1.0...
# 9               1  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 16              1  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 4               1  evening_ema: LifeSense/26 Passive Data Kit/1.0...
# 13              0  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 7               1  evening_ema: LifeSense/33 Passive Data Kit/1.0...
# 15              1  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 16              1  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 5               0  evening_ema: LifeSense/26 Passive Data Kit/1.0...
# 13              1  evening_ema: LifeSense/35 Passive Data Kit/1.0...
# 9               0  evening_ema: LifeSense/33 Passive Data Kit/1.0...
# 10              0  evening_ema: LifeSense/33 Passive Data Kit/1.0...
# 4               0  evening_ema: LifeSense/26 Passive Data Kit/1.0...
# 1               0  evening_ema: LifeSense/26 Passive Data Kit/1.0...
# 1               1  evening_ema: LifeSense/26 Passive Data Kit/1.0...
# 5               0  evening_ema: LifeSense/26 Passive Data Kit/1.0...
#
#    generator-id mood        pid place-home-other-0  ...   timestamp  \
# 18  evening_ema    5  p00746649                     ...  1570162309
# 1   evening_ema    5  p03939827                     ...  1564627356
# 3   evening_ema    6  p03939827                NaN  ...  1564756984
# 9   evening_ema    4  p08007329                     ...  1568479739
# 16  evening_ema    4  p09611865                     ...  1570031708
# 4   evening_ema    7  p12616311                     ...  1564900305
# 13  evening_ema    7  p26957252                     ...  1568423459
# 7   evening_ema    6  p29878406                     ...  1566625012
# 15  evening_ema    7  p45517860                     ...  1568558303
# 16  evening_ema    6  p45517860                NaN  ...  1568558313
# 5   evening_ema    5  p54841471                     ...  1564961848
# 13  evening_ema    6  p55915099                     ...  1568397697
# 9   evening_ema    5  p74739196                     ...  1566703622
# 10  evening_ema    5  p74739196                NaN  ...  1566703630
# 4   evening_ema    6  p79510141                     ...  1564866382
# 1   evening_ema    4  p81968737                     ...  1564623796
# 1   evening_ema    4  p84902402                     ...  1564634169
# 5   evening_ema    7  p98621494                     ...  1564969098
#
#                timezone timezone-offset for_yesterday_int      adj_ts  \
# 18      America/Chicago          -18000                 0  1570144309
# 1      America/New_York          -14400                 0  1564612956
# 3      America/New_York          -14400                 1  1564742584
# 9      America/New_York          -14400                 1  1568465339
# 16       America/Denver          -21600                 1  1570010108
# 4       America/Detroit          -14400                 1  1564885905
# 13     America/New_York          -14400                 0  1568409059
# 7      America/New_York          -14400                 1  1566610612
# 15       America/Denver          -21600                 1  1568536703
# 16       America/Denver          -21600                 1  1568536713
# 5       America/Chicago          -18000                 0  1564943848
# 13     America/New_York          -14400                 1  1568383297
# 9   America/Los_Angeles          -25200                 0  1566678422
# 10  America/Los_Angeles          -25200                 0  1566678430
# 4      America/New_York          -14400                 0  1564851982
# 1       America/Chicago          -18000                 0  1564605796
# 1      America/New_York          -14400                 1  1564619769
# 5       America/Chicago          -18000                 0  1564951098
#
#          date   adj_date time   adj_ts_next ts_diff
# 18 2019-10-03 2019-10-03   23  1.570144e+09    47.0
# 1  2019-07-31 2019-07-31   23  1.564613e+09     6.0
# 3  2019-08-02 2019-08-01   11  1.564743e+09     4.0
# 9  2019-09-14 2019-09-13   13  1.568465e+09    10.0
# 16 2019-10-02 2019-10-01   10  1.570010e+09     7.0
# 4  2019-08-04 2019-08-03    3  1.564886e+09    11.0
# 13 2019-09-13 2019-09-13   21  1.568409e+09    22.0
# 7  2019-08-24 2019-08-23    2  1.566611e+09    15.0
# 15 2019-09-15 2019-09-14    9  1.568537e+09    10.0
# 16 2019-09-15 2019-09-14    9  1.568537e+09     4.0
# 5  2019-08-04 2019-08-04   19  1.564944e+09    17.0
# 13 2019-09-13 2019-09-12   14  1.568383e+09    16.0
# 9  2019-08-24 2019-08-24   20  1.566678e+09     8.0
# 10 2019-08-24 2019-08-24   20  1.566678e+09     5.0
# 4  2019-08-03 2019-08-03   17  1.564852e+09    10.0
# 1  2019-07-31 2019-07-31   21  1.564606e+09    11.0
# 1  2019-08-01 2019-07-31    1  1.564620e+09    12.0
# 5  2019-08-04 2019-08-04   21  1.564951e+09     7.0
#
# [18 rows x 140 columns]

# %%
even_ema_sorted.loc[even_ema_sorted['date'] == '2019-08-04'].shape
# Out:
# (241, 140)

# %% [markdown]
# ## Missingness IDs

# %%
p_ids = [ 'p' + x for x in wave1_ids]

# %%
def get_zero_emas(df, start_date, end_date):
    sel_df = df.loc[(df['date'] >= start_date) & (df['date'] <= end_date)]
    incl_pids = sel_df['pid'].unique()
    return [pid for pid in p_ids if pid not in incl_pids]

# %%
ema_zero_df = pd.DataFrame(columns=dates)

for date_tup in dates:
