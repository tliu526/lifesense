# %%
# imports and constants
import json
import pickle
import datetime as dt

import gmaps
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import multiprocessing
import numpy as np
import pandas as pd
import pingouin as pg
import seaborn as sns

from IPython.display import display, HTML
import ipywidgets as widgets

# user imports
from utils.process_data import *
from utils.stats import *
from utils.lifesense_utils import *

# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %% [markdown]
# # Location

# %% [markdown]
# ## Circadean Rhythm Window Processing

# %%
def build_circ_window(pid, wk, start_date, end_date):
    """Builds circadean movement features within the given window.
    
    TODO refactor with build_circadean_stats
    
    Assumes that the start_date and end_date fall within the given week.
    
    
    Args:
        - pid (str): the participant id
        - wk (int): the study week to pull data from: 1, 4, 7, 10, 13, 16
        - fus_df (pd.DataFrame): a fus_df frame with properly formatted date columns
        - start_date (str): start date, yyyy-mm-dd
        - end_date (str): end date, yyyy-mm-dd
        
    Returns:
        - circ_df (pd.DataFrame): frame with circadean movement statistics calculated for the given time window
    """
    print(pid)
    loc = "/data/tliu/wk{}_ls_data/pdk-location/{}.df".format(wk, pid)
    fus_df = pd.read_pickle(loc)
    if fus_df.shape[0] < 1:
        return
    
    fus_df = format_raw_fus(fus_df)
    fus_df = fus_df[(fus_df['date'] >= start_date) & (fus_df['date'] <= end_date)]
    print(fus_df.shape)
    fus_df["is_wkday"] = (pd.to_datetime(fus_df['date']).dt.dayofweek < 5).astype(float)

    circ_df = pd.DataFrame()
    circ_df['pid'] = [pid]
    circ_df['circ_movt_tot'] = get_circadian_movement(fus_df) 
    circ_df['circ_movt_wkday'] = get_circadian_movement(fus_df.loc[fus_df['is_wkday'] == 1]) 
    circ_df['circ_movt_wkend'] = get_circadian_movement(fus_df.loc[fus_df['is_wkday'] == 0]) 
    
    return circ_df


def build_circ_dict(seq_df, target, pre_days=3, post_days=3):
    """Builds a (col, [vals]) dictionary for circ features.
    
    Has to be processed separately because circadean movement cannot be aggregated to daily values.
    """
    col_dict = {}

    cols = ['circ_movt_tot', 'circ_movt_wkday', 'circ_movt_wkend']
    for col in cols:
        col_dict[col] = []

    for idx, row in seq_df.iterrows():
        if pd.isna(row[target]):
            for col in cols:
                col_dict[col].append(np.nan)
            continue
        else:
            date = row['date']
            pid = row['pid']
            wk = row['study_wk']
            sel_df = build_circ_window(pid, wk, (date.floor('D') - pd.Timedelta(pre_days, unit='D')),                                      
                                                (date.floor('D') + pd.Timedelta(post_days, unit='D')))
            for col in cols:
                if sel_df is not None:
                    col_dict[col].append(sel_df[col])
                else:
                    col_dict[col].append(np.nan)
                
    return col_dict

# %%
# %%time

test = build_circ_window('56596866', 4, '2019-08-15', '2019-09-01')
test
# Out:
# 56596866
# (3846, 5)
# CPU times: user 488 ms, sys: 4.15 ms, total: 493 ms
# Wall time: 484 ms

# %%
test.head()
# Out:
#         pid  circ_movt_tot  circ_movt_wkday  circ_movt_wkend
# 0  56596866     -10.657614        -9.976178       -14.412289

# %%
# %%time

shift_df = pd.read_pickle("ls_data/phq_cluster_shift.df")
circ_dict = build_circ_dict(shift_df, 'phq_start', pre_days=14, post_days=-1)
# Out:
# 00746649
# (2355, 5)
# 00746649
# (2043, 5)
# 00746649
# (2284, 5)
# 00746649
# (2497, 5)
# 00746649
# (2731, 5)
# 00746649
# (1394, 5)
# 01225297
# (1505, 5)
# 01225297
# (0, 5)
# 01225297
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (1597, 5)
# 01225297
# (904, 5)
# 01254121
# (1313, 5)
# 01254121
# (2436, 5)
# 01254121
# (2731, 5)
# 01254121
# (2881, 5)
# 01254121
# (2894, 5)
# 01254121
# (2941, 5)
# 01495950
# (1263, 5)
# 01495950
# (1275, 5)
# 01495950
# (1199, 5)
# 01495950
# (2735, 5)
# 01495950
# (2698, 5)
# 01495950
# (2666, 5)
# 01766910
# (525, 5)
# 01766910
# (1531, 5)
# 01766910
# (2906, 5)
# 01766910
# (2978, 5)
# 01766910
# (2856, 5)
# 01766910
# (2908, 5)
# 02970060
# (2057, 5)
# 02970060
# (2960, 5)
# 02970060
# (3021, 5)
# 02970060
# (2720, 5)
# 02970060
# (2827, 5)
# 02970060
# (2868, 5)
# 03233601
# (1646, 5)
# 03233601
# (2046, 5)
# 03233601
# (3016, 5)
# 03233601
# (2945, 5)
# 03233601
# (3007, 5)
# 03578019
# (1783, 5)
# 03578019
# (2258, 5)
# 03578019
# (2853, 5)
# 03578019
# (2839, 5)
# 03578019
# (3037, 5)
# 03939827
# (295, 5)
# 03939827
# (754, 5)
# 03939827
# (327, 5)
# 03939827
# (106, 5)
# 03939827
# (891, 5)
# 04133537
# (2181, 5)
# 04133537
# (2965, 5)
# 04133537
# (2910, 5)
# 04133537
# (2808, 5)
# 04133537
# (2941, 5)
# 04133537
# (2035, 5)
# 04918121
# (371, 5)
# 04918121
# (429, 5)
# 04918121
# (2649, 5)
# 04918121
# (2750, 5)
# 04918121
# (2922, 5)
# 04918121
# (2991, 5)
# 06400675
# (1011, 5)
# 06400675
# (2508, 5)
# 06400675
# (2923, 5)
# 06400675
# (3002, 5)
# 06400675
# (2918, 5)
# 06400675
# (2991, 5)
# 06638392
# (929, 5)
# 06638392
# (684, 5)
# 06638392
# (2501, 5)
# 06638392
# (1514, 5)
# 06638392
# (1609, 5)
# 06638392
# (2417, 5)
# 07974290
# 07974290
# (456, 5)
# 07974290
# (495, 5)
# 07974290
# (613, 5)
# 07974290
# (288, 5)
# 08007167
# (1905, 5)
# 08007167
# (2657, 5)
# 08007167
# (2605, 5)
# 08007167
# (2974, 5)
# 08007167
# (2885, 5)
# 08007167
# (2867, 5)
# 08103884
# (1743, 5)
# 08103884
# (2263, 5)
# 08103884
# (2693, 5)
# 08103884
# (2810, 5)
# 08103884
# (2754, 5)
# 08103884
# (1158, 5)
# 09489685
# (2235, 5)
# 09489685
# (1296, 5)
# 09489685
# (2724, 5)
# 09489685
# (2415, 5)
# 09489685
# (1113, 5)
# 09611865
# (1721, 5)
# 09611865
# (3157, 5)
# 09611865
# (3052, 5)
# 09611865
# (3050, 5)
# 09611865
# (738, 5)
# 09611865
# (1067, 5)
# 10099555
# (2597, 5)
# 10099555
# (2925, 5)
# 10099555
# (2613, 5)
# 10099555
# (2834, 5)
# 10099555
# (2951, 5)
# 10099555
# (1464, 5)
# 10285142
# (1941, 5)
# 10285142
# (3202, 5)
# 10285142
# (1982, 5)
# 10285142
# (870, 5)
# 10285142
# (1053, 5)
# 10285142
# (1615, 5)
# 11770862
# (127, 5)
# 11770862
# (0, 5)
# 11770862
# (391, 5)
# 11770862
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (484, 5)
# 11770862
# (0, 5)
# 11927637
# (1383, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 11927637
# (1972, 5)
# 11927637
# (1906, 5)
# 11927637
# (1597, 5)
# 11927637
# (1477, 5)
# 12807049
# (1214, 5)
# 12807049
# (1408, 5)
# 12807049
# (2155, 5)
# 12807049
# (3063, 5)
# 12807049
# (3165, 5)
# 12807049
# (1706, 5)
# 13051775
# (2785, 5)
# 13051775
# (1508, 5)
# 13051775
# (1575, 5)
# 13051775
# (2887, 5)
# 13051775
# (2747, 5)
# 13051775
# (1492, 5)
# 13250317
# (1919, 5)
# 13250317
# (1988, 5)
# 13250317
# (2856, 5)
# 13250317
# (2941, 5)
# 13250317
# (2841, 5)
# 13250317
# (1589, 5)
# 14113160
# (2088, 5)
# 14113160
# (2474, 5)
# 14113160
# (2701, 5)
# 14113160
# (2669, 5)
# 14113160
# (2761, 5)
# 14113160
# (1493, 5)
# 14196469
# (1874, 5)
# 14196469
# (1167, 5)
# 14549710
# (1353, 5)
# 14549710
# (1838, 5)
# 14549710
# (2149, 5)
# 14549710
# (2346, 5)
# 14549710
# (2444, 5)
# 14549710
# (1090, 5)
# 14753485
# (1865, 5)
# 14753485
# (2548, 5)
# 14753485
# (3015, 5)
# 14753485
# (2938, 5)
# 14753485
# (3231, 5)
# 14753485
# (1579, 5)
# 16777771
# (228, 5)
# 16777771
# (22, 5)
# 16777771
# (17, 5)
# 16777771
# (15, 5)
# 16777771
# (18, 5)
# 17294720
# (1119, 5)
# 17294720
# (1128, 5)
# 18583649
# (1287, 5)
# 18583649
# (3210, 5)
# 18583649
# (2806, 5)
# 18583649
# (1605, 5)
# 18583649
# (2971, 5)
# 18583649
# (2868, 5)
# 18740846
# (960, 5)
# 18740846
# (1436, 5)
# 18740846
# (1556, 5)
# 18740846
# (1314, 5)
# 18740846
# (1396, 5)
# 19410615
# (2694, 5)
# 19663467
# (1022, 5)
# 19663467
# (993, 5)
# 19663467
# (2261, 5)
# 19663467
# (2146, 5)
# 19663467
# (1930, 5)
# 19663467
# (1010, 5)
# 19674187
# (1849, 5)
# 19674187
# (2862, 5)
# 19674187
# (2926, 5)
# 19674187
# (1560, 5)
# 19674187
# (2747, 5)
# 19674187
# (2782, 5)
# 20206315
# (1432, 5)
# 20206315
# (1633, 5)
# 20206315
# (1712, 5)
# 20206315
# (2031, 5)
# 20206315
# (1406, 5)
# 20206315
# (562, 5)
# 20706360
# (1994, 5)
# 20706360
# (3176, 5)
# 20706360
# (3118, 5)
# 20706360
# (2579, 5)
# 20706360
# (615, 5)
# 20706360
# (478, 5)
# 21150752
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (621, 5)
# 21150752
# (2586, 5)
# 21150752
# (1495, 5)
# 21150752
# (2949, 5)
# 21594071
# (2105, 5)
# 21594071
# (2689, 5)
# 21594071
# (2573, 5)
# 21594071
# (2354, 5)
# 21594071
# (2704, 5)
# 21594071
# (2879, 5)
# 22086591
# (1977, 5)
# 22086591
# (2749, 5)
# 22086591
# (2906, 5)
# 22086591
# (2933, 5)
# 22086591
# (2903, 5)
# 22086591
# (2930, 5)
# 22352222
# (2841, 5)
# 22352222
# (2835, 5)
# 22352222
# (2093, 5)
# 22352222
# (2711, 5)
# 22352222
# (2695, 5)
# 22352222
# (1380, 5)
# 22498610
# (1734, 5)
# 22498610
# (2026, 5)
# 22498610
# (258, 5)
# 23066392
# (1477, 5)
# 23066392
# (3135, 5)
# 23066392
# (2940, 5)
# 23066392
# (3072, 5)
# 23066392
# (3051, 5)
# 23066392
# (2975, 5)
# 23388083
# (1337, 5)
# 23388083
# (2345, 5)
# 23388083
# (2502, 5)
# 23388083
# (2444, 5)
# 24936642
# (1729, 5)
# 24936642
# (2699, 5)
# 24936642
# (2473, 5)
# 24936642
# (2409, 5)
# 24936642
# (2661, 5)
# 24936642
# (2485, 5)
# 26080346
# (1604, 5)
# 26080346
# (2549, 5)
# 26080346
# (1967, 5)
# 26080346
# (2265, 5)
# 26080346
# (469, 5)
# 26957252
# (2312, 5)
# 26957252
# (2512, 5)
# 26957252
# (2887, 5)
# 26957252
# (2905, 5)
# 26957252
# (2785, 5)
# 26957252
# (1480, 5)
# 27330785
# (2096, 5)
# 27330785
# (2000, 5)
# 27330785
# (2351, 5)
# 27330785
# (1372, 5)
# 27330785
# (1227, 5)
# 27762780
# (1098, 5)
# 27762780
# (3002, 5)
# 27762780
# (3187, 5)
# 27762780
# (2908, 5)
# 27762780
# (2835, 5)
# 27762780
# (2864, 5)
# 28021601
# (1243, 5)
# 28021601
# (780, 5)
# 28244292
# (1377, 5)
# 28244292
# (606, 5)
# 28244292
# (411, 5)
# 28458341
# (2302, 5)
# 28458341
# (3170, 5)
# 28458341
# (2308, 5)
# 28458341
# (3173, 5)
# 28458341
# (3497, 5)
# 28458341
# (3397, 5)
# 28939704
# (1925, 5)
# 28939704
# (546, 5)
# 28939704
# (795, 5)
# 28939704
# (985, 5)
# 28949890
# (2136, 5)
# 28949890
# (3205, 5)
# 28949890
# (3092, 5)
# 28949890
# (3053, 5)
# 28949890
# (1079, 5)
# 28949890
# (1414, 5)
# 29149362
# (624, 5)
# 29149362
# (1902, 5)
# 29149362
# (1738, 5)
# 29149362
# (2686, 5)
# 29149362
# (2622, 5)
# 29149362
# (1567, 5)
# 29584096
# (292, 5)
# 30501084
# (2300, 5)
# 30501084
# (2546, 5)
# 30501084
# (2650, 5)
# 30501084
# (1235, 5)
# 30501084
# (649, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 31456993
# (1834, 5)
# 31456993
# (3109, 5)
# 31456993
# (3023, 5)
# 31456993
# (3037, 5)
# 31456993
# (3055, 5)
# 31456993
# (2979, 5)
# 31477083
# (1834, 5)
# 31477083
# (988, 5)
# 31477083
# (1383, 5)
# 31477083
# (2691, 5)
# 31477083
# (2654, 5)
# 31477083
# (2631, 5)
# 31574721
# (2045, 5)
# 31574721
# (2331, 5)
# 31574721
# (1784, 5)
# 31574721
# (1119, 5)
# 31574721
# (1211, 5)
# 32573840
# (138, 5)
# 32573840
# (27, 5)
# 32573840
# (7, 5)
# 32718334
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (1700, 5)
# 32718334
# (1604, 5)
# 32718334
# (1798, 5)
# 32718334
# (1818, 5)
# 32718334
# (1638, 5)
# 32718334
# (1785, 5)
# 32888746
# (316, 5)
# 32888746
# (563, 5)
# 32888746
# (780, 5)
# 32888746
# (762, 5)
# 32888746
# (915, 5)
# 32888746
# (476, 5)
# 33250639
# (41, 5)
# 33250639
# (2823, 5)
# 33250639
# (3009, 5)
# 33250639
# (2907, 5)
# 33250639
# (1560, 5)
# 35493515
# (1774, 5)
# 35493515
# (277, 5)
# 35493515
# (2088, 5)
# 36969413
# (176, 5)
# 36969413
# (375, 5)
# 36969413
# (1214, 5)
# 36969413
# (521, 5)
# 36969413
# (37, 5)
# 37168430
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2131, 5)
# 37168430
# (1251, 5)
# 37168430
# (900, 5)
# 37168430
# (2839, 5)
# 37168430
# (2897, 5)
# 38459884
# (2426, 5)
# 38459884
# (2262, 5)
# 38459884
# (2521, 5)
# 38459884
# (2468, 5)
# 38459884
# (2420, 5)
# 38459884
# (2239, 5)
# 38588231
# (77, 5)
# 38588231
# (60, 5)
# 38588231
# (138, 5)
# 38588231
# (350, 5)
# 38588231
# (483, 5)
# 38588231
# (203, 5)
# 38646138
# (1774, 5)
# 38646138
# (2403, 5)
# 38646138
# (2136, 5)
# 38646138
# (2406, 5)
# 38646138
# (2275, 5)
# 38646138
# (2330, 5)
# 38890840
# (1062, 5)
# 38890840
# (2942, 5)
# 38890840
# (2798, 5)
# 38890840
# (3018, 5)
# 38890840
# (2887, 5)
# 38890840
# (2977, 5)
# 39548248
# (935, 5)
# 39548248
# (1459, 5)
# 39548248
# (1883, 5)
# 39548248
# (1235, 5)
# 39548248
# (1741, 5)
# 39548248
# (1433, 5)
# 39561926
# (743, 5)
# 39561926
# (2299, 5)
# 39561926
# (1290, 5)
# 39561926
# (2381, 5)
# 39561926
# (2511, 5)
# 39561926
# (2892, 5)
# 39725031
# (1857, 5)
# 39725031
# (1893, 5)
# 39725031
# (3271, 5)
# 39725031
# (3008, 5)
# 39725031
# (2531, 5)
# 39725031
# (3087, 5)
# 39854689
# (1768, 5)
# 39854689
# (2725, 5)
# 39854689
# (1742, 5)
# 39854689
# (1686, 5)
# 39854689
# (2598, 5)
# 39854689
# (2612, 5)
# 40932643
# (667, 5)
# 40932643
# (293, 5)
# 40932643
# (367, 5)
# 40932643
# (272, 5)
# 40932643
# (258, 5)
# 40932643
# (232, 5)
# 41606321
# (1950, 5)
# 41606321
# (2351, 5)
# 41606321
# (2624, 5)
# 41606321
# (2939, 5)
# 41606321
# (1582, 5)
# 41606321
# (1620, 5)
# 42215399
# (678, 5)
# 42215399
# (1647, 5)
# 42215399
# (3118, 5)
# 42215399
# (3272, 5)
# 42871706
# (42, 5)
# 42871706
# (13, 5)
# 42871706
# (1, 5)
# 42871706
# (66, 5)
# 43093019
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2343, 5)
# 43093019
# (2021, 5)
# 43093019
# (2313, 5)
# 44655272
# (1586, 5)
# 44655272
# (816, 5)
# 44655272
# (1162, 5)
# 44655272
# (1403, 5)
# 44655272
# (674, 5)
# 44909649
# (2950, 5)
# 44909649
# (2413, 5)
# 44909649
# (2638, 5)
# 44909649
# (2848, 5)
# 44909649
# (3224, 5)
# 44909649
# (1635, 5)
# 44933937
# (1668, 5)
# 44933937
# (1553, 5)
# 44933937
# (585, 5)
# 44933937
# (1663, 5)
# 44933937
# (2079, 5)
# 45433155
# (1575, 5)
# 45433155
# (2624, 5)
# 45433155
# (2836, 5)
# 45433155
# (2757, 5)
# 45433155
# (2814, 5)
# 45433155
# (2670, 5)
# 45517860
# (1736, 5)
# 45517860
# (1334, 5)
# 45517860
# (2895, 5)
# 45517860
# (2743, 5)
# 45517860
# (591, 5)
# 45517860
# (813, 5)
# 45761494
# (2163, 5)
# 46002724
# (1846, 5)
# 46002724
# (2412, 5)
# 46002724
# (2433, 5)
# 46002724
# (2501, 5)
# 46002724
# (1340, 5)
# 46175798
# (2401, 5)
# 46175798
# (2107, 5)
# 46175798
# (2635, 5)
# 46175798
# (1555, 5)
# 46175798
# (2564, 5)
# 46222210
# (2074, 5)
# 46222210
# (2132, 5)
# 46222210
# (2759, 5)
# 46222210
# (2795, 5)
# 46222210
# (2771, 5)
# 46222210
# (2978, 5)
# 47363974
# (1814, 5)
# 47363974
# (1441, 5)
# 47363974
# (2994, 5)
# 47363974
# (2897, 5)
# 47363974
# (2820, 5)
# 47363974
# (2879, 5)
# 47688944
# (533, 5)
# 47688944
# (3268, 5)
# 47688944
# (3104, 5)
# 47688944
# (3026, 5)
# 48315222
# (1102, 5)
# 48315222
# (2496, 5)
# 48315222
# (2970, 5)
# 48315222
# (1147, 5)
# 48315222
# (1918, 5)
# 48625414
# (1007, 5)
# 48625414
# (2229, 5)
# 48625414
# (1648, 5)
# 48625414
# (2694, 5)
# 48625414
# (3093, 5)
# 48625414
# (2852, 5)
# 50550619
# (1225, 5)
# 50550619
# (3040, 5)
# 50550619
# (3012, 5)
# 50550619
# (3048, 5)
# 50550619
# (2685, 5)
# 50550619
# (2847, 5)
# 50707558
# (2629, 5)
# 50707558
# (2746, 5)
# 50707558
# (2974, 5)
# 50707558
# (2844, 5)
# 50707558
# (2761, 5)
# 50707558
# (1567, 5)
# 50730294
# (677, 5)
# 50730294
# (1779, 5)
# 50730294
# (3046, 5)
# 50730294
# (3241, 5)
# 50730294
# (3137, 5)
# 50730294
# (1782, 5)
# 50765631
# (997, 5)
# 50765631
# (2525, 5)
# 50765631
# (2699, 5)
# 50765631
# (1829, 5)
# 50765631
# (1734, 5)
# 50765631
# (1448, 5)
# 50931782
# (1486, 5)
# 50931782
# (2048, 5)
# 50931782
# (2676, 5)
# 50931782
# (1845, 5)
# 50931782
# (1765, 5)
# 50931782
# (2057, 5)
# 51419094
# (2521, 5)
# 51419094
# (2084, 5)
# 51419094
# (2743, 5)
# 51419094
# (2828, 5)
# 51419094
# (2753, 5)
# 51419094
# (1542, 5)
# 51735262
# (1079, 5)
# 51735262
# (1366, 5)
# 51735262
# (1607, 5)
# 51735262
# (1449, 5)
# 51735262
# (2432, 5)
# 51735262
# (2764, 5)
# 52064875
# (2021, 5)
# 52064875
# (2695, 5)
# 52064875
# (2649, 5)
# 52064875
# (2770, 5)
# 52064875
# (2972, 5)
# 52064875
# (3043, 5)
# 52581458
# (1453, 5)
# 52581458
# (2716, 5)
# 52581458
# (2890, 5)
# 52581458
# (2836, 5)
# 52581458
# (2749, 5)
# 52581458
# (2666, 5)
# 52982527
# (1550, 5)
# 53097921
# (1593, 5)
# 53097921
# (703, 5)
# 53097921
# (2015, 5)
# 53097921
# (1927, 5)
# 53097921
# (883, 5)
# 53097921
# (2200, 5)
# 53874087
# (1943, 5)
# 54004910
# (1596, 5)
# 54004910
# (1583, 5)
# 54004910
# (2722, 5)
# 54004910
# (2719, 5)
# 54004910
# (2473, 5)
# 54004910
# (1381, 5)
# 54461187
# (1912, 5)
# 54461187
# (2704, 5)
# 54461187
# (1342, 5)
# 54461187
# (1198, 5)
# 54461187
# (1479, 5)
# 54461187
# (1713, 5)
# 54841471
# (1203, 5)
# 54841471
# (2190, 5)
# 54841471
# (2591, 5)
# 54841471
# (2253, 5)
# 54841471
# (817, 5)
# 54841471
# (1503, 5)
# 55313474
# (1219, 5)
# 55313474
# (2672, 5)
# 55313474
# (2941, 5)
# 55313474
# (2922, 5)
# 55313474
# (2811, 5)
# 55313474
# (1553, 5)
# 55542659
# (1358, 5)
# 55542659
# (1064, 5)
# 55542659
# (2191, 5)
# 55542659
# (1922, 5)
# 55542659
# (1790, 5)
# 55542659
# (2702, 5)
# 55915099
# (1443, 5)
# 55915099
# (1900, 5)
# 55915099
# (1967, 5)
# 55915099
# (2124, 5)
# 55915099
# (1258, 5)
# 55915099
# (815, 5)
# 56723660
# (2083, 5)
# 56723660
# (2776, 5)
# 56723660
# (2204, 5)
# 56723660
# (2710, 5)
# 56723660
# (2840, 5)
# 56723660
# (2429, 5)
# 56910929
# (167, 5)
# 56910929
# (1119, 5)
# 56910929
# (711, 5)
# 56910929
# (547, 5)
# 56910929
# (964, 5)
# 56910929
# (200, 5)
# 56912666
# (2519, 5)
# 57473014
# (2093, 5)
# 57473014
# (2592, 5)
# 57473014
# (2788, 5)
# 57473014
# (2771, 5)
# 57473014
# (2843, 5)
# 57473014
# (2786, 5)
# 58093242
# (756, 5)
# 58093242
# (1747, 5)
# 58093242
# (2253, 5)
# 58093242
# (2301, 5)
# 58093242
# (2320, 5)
# 58093242
# (2235, 5)
# 58740880
# (2327, 5)
# 58740880
# (2758, 5)
# 58740880
# (3063, 5)
# 58740880
# (2814, 5)
# 58740880
# (3004, 5)
# 58740880
# (1585, 5)
# 58780031
# (2204, 5)
# 58780031
# (2978, 5)
# 58780031
# (3459, 5)
# 58780031
# (1479, 5)
# 58780031
# (891, 5)
# 58780031
# (1823, 5)
# 59222410
# (898, 5)
# 59222410
# (529, 5)
# 59222410
# (911, 5)
# 59222410
# (657, 5)
# 59654069
# (894, 5)
# 59654069
# (1955, 5)
# 59654069
# (2812, 5)
# 59654069
# (4788, 5)
# 59654069
# (1637, 5)
# 59764431
# (654, 5)
# 59764431
# (1286, 5)
# 59764431
# (1347, 5)
# 59764431
# (1329, 5)
# 59764431
# (1367, 5)
# 61131074
# (684, 5)
# 61131074
# (2849, 5)
# 61131074
# (2682, 5)
# 61131074
# (2837, 5)
# 61131074
# (3216, 5)
# 61131074
# (3281, 5)
# 61762096
# (1653, 5)
# 61762096
# (1668, 5)
# 61762096
# (2758, 5)
# 61762096
# (1893, 5)
# 61762096
# (2538, 5)
# 61762096
# (2627, 5)
# 62375942
# (2835, 5)
# 62375942
# (3024, 5)
# 62375942
# (3091, 5)
# 62375942
# (3346, 5)
# 62375942
# (3483, 5)
# 62375942
# (1505, 5)
# 62463869
# (904, 5)
# 62463869
# (3047, 5)
# 62463869
# (3243, 5)
# 62463869
# (2894, 5)
# 62463869
# (3033, 5)
# 62599280
# (177, 5)
# 62599280
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (451, 5)
# 62599280
# (653, 5)
# 62599280
# (95, 5)
# 62599280
# (33, 5)
# 62808613
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (1310, 5)
# 62808613
# (2707, 5)
# 62808613
# (2572, 5)
# 62808613
# (2739, 5)
# 62808613
# (2593, 5)
# 62808613
# (1529, 5)
# 62860600
# (805, 5)
# 62860600
# (1651, 5)
# 62860600
# (1255, 5)
# 62860600
# (701, 5)
# 62860600
# (514, 5)
# 62860600
# (985, 5)
# 64142475
# (1798, 5)
# 64142475
# (2522, 5)
# 64142475
# (2554, 5)
# 64142475
# (819, 5)
# 64142475
# (1129, 5)
# 64142475
# (823, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 64292248
# (1282, 5)
# 64292248
# (888, 5)
# 64292248
# (1839, 5)
# 64292248
# (1004, 5)
# 64292248
# (1623, 5)
# 64292248
# (1237, 5)
# 65143770
# (1443, 5)
# 65143770
# (2093, 5)
# 65143770
# (2854, 5)
# 65143770
# (3083, 5)
# 65143770
# (3026, 5)
# 65143770
# (2988, 5)
# 65149091
# (1905, 5)
# 65149091
# (2803, 5)
# 65149091
# (873, 5)
# 65149091
# (1214, 5)
# 65149091
# (221, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 65149091
# (437, 5)
# 65381988
# (2909, 5)
# 65381988
# (3261, 5)
# 65381988
# (3241, 5)
# 65381988
# (3268, 5)
# 65381988
# (1629, 5)
# 65381988
# (3136, 5)
# 65696941
# (1753, 5)
# 65741560
# (785, 5)
# 65741560
# (2430, 5)
# 65741560
# (2144, 5)
# 65741560
# (2511, 5)
# 65741560
# (2252, 5)
# 65741560
# (2247, 5)
# 66507502
# (1783, 5)
# 66507502
# (2756, 5)
# 66507502
# (2841, 5)
# 66507502
# (3039, 5)
# 66507502
# (2821, 5)
# 66507502
# (3114, 5)
# 66873010
# (294, 5)
# 66873010
# (744, 5)
# 66873010
# (1218, 5)
# 66873010
# (1420, 5)
# 66873010
# (584, 5)
# 66873010
# (855, 5)
# 67597747
# (580, 5)
# 67597747
# (1475, 5)
# 67597747
# (1651, 5)
# 67597747
# (1438, 5)
# 67597747
# (1594, 5)
# 67597747
# (2032, 5)
# 67615491
# (1327, 5)
# 67615491
# (2227, 5)
# 67615491
# (2598, 5)
# 67615491
# (2833, 5)
# 67615491
# (2699, 5)
# 67615491
# (2700, 5)
# 67900112
# (1686, 5)
# 67900112
# (1524, 5)
# 68744652
# (1585, 5)
# 68744652
# (1870, 5)
# 68744652
# (2151, 5)
# 68744652
# (1962, 5)
# 68744652
# (1679, 5)
# 68744652
# (1808, 5)
# 69335292
# (1164, 5)
# 69335292
# (1796, 5)
# 69335292
# (2430, 5)
# 69335292
# (2385, 5)
# 69335292
# (1714, 5)
# 69335292
# (982, 5)
# 69452375
# (1653, 5)
# 69452375
# (2313, 5)
# 69452375
# (2227, 5)
# 69452375
# (2372, 5)
# 69452375
# (2499, 5)
# 69452375
# (1033, 5)
# 70027963
# (1383, 5)
# 70483015
# (2709, 5)
# 71043609
# (1076, 5)
# 71043609
# (1726, 5)
# 71043609
# (1717, 5)
# 71043609
# (717, 5)
# 71043609
# (985, 5)
# 71189891
# (894, 5)
# 71189891
# (1048, 5)
# 71189891
# (2487, 5)
# 71189891
# (2444, 5)
# 71189891
# (2419, 5)
# 71189891
# (2552, 5)
# 71219000
# (1346, 5)
# 71219000
# (2176, 5)
# 71219000
# (2355, 5)
# 71219000
# (2111, 5)
# 71219000
# (1877, 5)
# 71676393
# (1136, 5)
# 71676393
# (1475, 5)
# 71676393
# (479, 5)
# 71676393
# (1676, 5)
# 71676393
# (847, 5)
# 71676393
# (1272, 5)
# 72038219
# (2111, 5)
# 72038219
# (1990, 5)
# 72038219
# (1542, 5)
# 72038219
# (0, 5)
# 72038219
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2631, 5)
# 72038219
# (1678, 5)
# 72685265
# (1705, 5)
# 72685265
# (2630, 5)
# 72685265
# (3081, 5)
# 72685265
# (3160, 5)
# 72685265
# (3189, 5)
# 72685265
# (3100, 5)
# 73142171
# (1423, 5)
# 73142171
# (3303, 5)
# 73142171
# (3119, 5)
# 73142171
# (3170, 5)
# 73142171
# (1869, 5)
# 73326278
# (1025, 5)
# 73326278
# (1800, 5)
# 73326278
# (2513, 5)
# 73326278
# (2198, 5)
# 73916801
# (57, 5)
# 73916801
# (287, 5)
# 73916801
# (601, 5)
# 73916801
# (344, 5)
# 73916801
# (391, 5)
# 73916801
# (608, 5)
# 73960495
# (2001, 5)
# 73960495
# (2726, 5)
# 74575289
# (1694, 5)
# 74575289
# (2496, 5)
# 74575289
# (2853, 5)
# 74575289
# (2900, 5)
# 74575289
# (2759, 5)
# 74575289
# (1526, 5)
# 74626135
# (1779, 5)
# 74626135
# (866, 5)
# 74626135
# (1514, 5)
# 74626135
# (1887, 5)
# 74626135
# (1814, 5)
# 74626135
# (2195, 5)
# 74739196
# (1906, 5)
# 74739196
# (2962, 5)
# 74739196
# (2887, 5)
# 74739196
# (2596, 5)
# 74739196
# (2797, 5)
# 74739196
# (2913, 5)
# 75282136
# (2094, 5)
# 75282136
# (2669, 5)
# 75282136
# (2506, 5)
# 75282136
# (2773, 5)
# 75282136
# (2678, 5)
# 75282136
# (1492, 5)
# 75348018
# (2082, 5)
# 75348018
# (997, 5)
# 75348018
# (1671, 5)
# 75348018
# (792, 5)
# 75348018
# (19, 5)
# 75437581
# (2063, 5)
# 75437581
# (2612, 5)
# 75437581
# (2900, 5)
# 75437581
# (2763, 5)
# 75437581
# (2828, 5)
# 75437581
# (1474, 5)
# 76432041
# (1460, 5)
# 76432041
# (983, 5)
# 76432041
# (2480, 5)
# 76432041
# (2314, 5)
# 76432041
# (2570, 5)
# 76432041
# (1452, 5)
# 76854891
# (1596, 5)
# 77579838
# (1967, 5)
# 77579838
# (634, 5)
# 77579838
# (1763, 5)
# 77579838
# (2142, 5)
# 77579838
# (1662, 5)
# 77579838
# (33, 5)
# 78352234
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2147, 5)
# 78352234
# (2803, 5)
# 78352234
# (3025, 5)
# 78352234
# (3321, 5)
# 78352234
# (1645, 5)
# 78352234
# (3218, 5)
# 78681731
# (2115, 5)
# 78681731
# (2582, 5)
# 78681731
# (1812, 5)
# 78681731
# (2693, 5)
# 78681731
# (1513, 5)
# 78681731
# (1453, 5)
# 78911129
# (1741, 5)
# 78911129
# (2842, 5)
# 78911129
# (2015, 5)
# 78911129
# (555, 5)
# 78911129
# (790, 5)
# 78911129
# (1542, 5)
# 79316475
# (2196, 5)
# 79316475
# (1283, 5)
# 79316475
# (2746, 5)
# 79316475
# (2772, 5)
# 79316475
# (2619, 5)
# 79316475
# (2814, 5)
# 79439002
# (1786, 5)
# 79439002
# (2248, 5)
# 79439002
# (1892, 5)
# 79439002
# (2274, 5)
# 79439002
# (2673, 5)
# 79819446
# (1228, 5)
# 79819446
# (2930, 5)
# 79819446
# (2267, 5)
# 79819446
# (1937, 5)
# 79819446
# (3011, 5)
# 79819446
# (1644, 5)
# 80206225
# (793, 5)
# 80206225
# (3123, 5)
# 80206225
# (3057, 5)
# 80206225
# (3622, 5)
# 80206225
# (3567, 5)
# 80206225
# (3491, 5)
# 80504454
# (2367, 5)
# 80504454
# (2704, 5)
# 80504454
# (2923, 5)
# 80504454
# (2858, 5)
# 80504454
# (2828, 5)
# 80657933
# (1592, 5)
# 80657933
# (2096, 5)
# 80657933
# (2323, 5)
# 80657933
# (2546, 5)
# 80657933
# (2520, 5)
# 80657933
# (2222, 5)
# 81049144
# (1965, 5)
# 81049144
# (2337, 5)
# 81049144
# (2621, 5)
# 81049144
# (2550, 5)
# 81049144
# (1891, 5)
# 81049144
# (2666, 5)
# 81249330
# (1688, 5)
# 81249330
# (1087, 5)
# 81249330
# (339, 5)
# 81249330
# (369, 5)
# 81249330
# (900, 5)
# 81720300
# (1725, 5)
# 81720300
# (620, 5)
# 81720300
# (1710, 5)
# 81720300
# (1824, 5)
# 81729157
# (1809, 5)
# 81729157
# (3062, 5)
# 81729157
# (2821, 5)
# 81729157
# (2996, 5)
# 81729157
# (2869, 5)
# 81729157
# (3115, 5)
# 82727218
# (2009, 5)
# 82727218
# (2852, 5)
# 82727218
# (3271, 5)
# 82727218
# (3417, 5)
# 82727218
# (3415, 5)
# 82727218
# (3401, 5)
# 83056303
# (849, 5)
# 83056303
# (2346, 5)
# 83056303
# (1996, 5)
# 83056303
# (2061, 5)
# 83056303
# (2030, 5)
# 83056303
# (2008, 5)
# 83085276
# (743, 5)
# 83085276
# (2703, 5)
# 83085276
# (2759, 5)
# 83085276
# (2424, 5)
# 83085276
# (1513, 5)
# 83275234
# (707, 5)
# 83275234
# (1506, 5)
# 84877086
# (0, 5)
# 84877086
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2516, 5)
# 84877086
# (2692, 5)
# 84877086
# (1494, 5)
# 84902402
# (1779, 5)
# 84902402
# (2928, 5)
# 84902402
# (3329, 5)
# 84902402
# (2883, 5)
# 84902402
# (3036, 5)
# 84902402
# (3055, 5)
# 85752121
# (1534, 5)
# 85752121
# (2416, 5)
# 85752121
# (2861, 5)
# 85752121
# (2299, 5)
# 85752121
# (2884, 5)
# 85752121
# (1634, 5)
# 86283726
# (2352, 5)
# 86283726
# (2519, 5)
# 86283726
# (2872, 5)
# 86756971
# (1250, 5)
# 86756971
# (2695, 5)
# 86756971
# (2998, 5)
# 86756971
# (2174, 5)
# 86756971
# (1518, 5)
# 86756971
# (1837, 5)
# 87400142
# (1986, 5)
# 87400142
# (2692, 5)
# 87400142
# (3315, 5)
# 87400142
# (2892, 5)
# 87400142
# (2496, 5)
# 87400142
# (2313, 5)
# 87485171
# (1917, 5)
# 87485171
# (1636, 5)
# 87485171
# (2066, 5)
# 87485171
# (2842, 5)
# 87485171
# (3006, 5)
# 87485171
# (2597, 5)
# 89057862
# (1263, 5)
# 89057862
# (3372, 5)
# 89057862
# (3239, 5)
# 89057862
# (3294, 5)
# 89057862
# (3130, 5)
# 89057862
# (3236, 5)
# 89434074
# (2742, 5)
# 89434074
# (2479, 5)
# 89434074
# (3003, 5)
# 89434074
# (356, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 89434074
# (868, 5)
# 89434074
# (1709, 5)
# 90229239
# (1695, 5)
# 90229239
# (196, 5)
# 90229239
# (581, 5)
# 90229239
# (526, 5)
# 90587846
# (2724, 5)
# 90587846
# (2918, 5)
# 90587846
# (3142, 5)
# 90587846
# (2848, 5)
# 90587846
# (1660, 5)
# 90587846
# (1359, 5)
# 90638927
# (27, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 90638927
# (2502, 5)
# 90638927
# (2292, 5)
# 90638927
# (2557, 5)
# 90638927
# (2756, 5)
# 90638927
# (1668, 5)
# 90763832
# (2236, 5)
# 90763832
# (3035, 5)
# 90763832
# (3155, 5)
# 90763832
# (3077, 5)
# 90763832
# (3065, 5)
# 90763832
# (3077, 5)
# 91048552
# (2043, 5)
# 91048552
# (2870, 5)
# 91048552
# (2632, 5)
# 91048552
# (1254, 5)
# 91048552
# (1177, 5)
# 91048552
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (1719, 5)
# 91788916
# 91788916
# (0, 5)
# 93606382
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/scipy/signal/spectral.py:151: RuntimeWarning: Mean of empty slice.
#   pgram = _lombscargle(x, y - y.mean(), freqs)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# (2133, 5)
# 93606382
# (2251, 5)
# 93606382
# (2886, 5)
# 93606382
# (1607, 5)
# 93606382
# (1553, 5)
# 93606382
# (3026, 5)
# 93627939
# (2075, 5)
# 93627939
# (969, 5)
# 94277599
# (2246, 5)
# 94277599
# (2409, 5)
# 94277599
# (2548, 5)
# 94277599
# (2286, 5)
# 94277599
# (1182, 5)
# 97678130
# (1264, 5)
# 97678130
# (1541, 5)
# 97678130
# (2102, 5)
# 97678130
# (1897, 5)
# 97678130
# (355, 5)
# 97678130
# (2353, 5)
# 98250113
# (1132, 5)
# 98250113
# (2331, 5)
# 98250113
# (2729, 5)
# 98250113
# (2718, 5)
# 98250113
# (2704, 5)
# 98250113
# (2742, 5)
# 98621494
# (1603, 5)
# 98621494
# (2848, 5)
# 98621494
# (2775, 5)
# 98621494
# (2850, 5)
# 98621494
# (2374, 5)
# 99127649
# (1396, 5)
# 99127649
# (1626, 5)
# 99127649
# (706, 5)
# 99127649
# (3163, 5)
# 99127649
# (1533, 5)
# 99338619
# (1432, 5)
# 99338619
# (2941, 5)
# 99338619
# (3375, 5)
# 99338619
# (3101, 5)
# 99338619
# (1207, 5)
# CPU times: user 5min 42s, sys: 21.3 s, total: 6min 3s
# Wall time: 6min 5s

# %% [markdown]
# ## Fused location correctness analysis

# %%
fus_daily = pd.read_pickle("ls_data/wk10/fus_daily.df")

# %%
fus_daily[fus_daily['velocity'] < 0]
# Out:
#          pid       date          dist   entropy  cluster  loc_var   velocity
# 16  61762096 2019-10-10  16801.665292  0.485634       29  7.57562 -29.441542

# %%
raw_fus = pd.read_pickle("/data/tliu/wk10_ls_data/pdk-location/61762096.df")

# %%
fus_df = format_raw_fus(raw_fus)
fus_df = fus_df[(fus_df['date'] <= '2019-10-11') & (fus_df['date'] >= '2019-10-09')]
fus_df = fus_df.reset_index(drop=True).reset_index()
#display(fus_df[100:150])
#fus_df = fus_df.sort_values('timestamp')
#display(fus_df[100:150])
df1, df2 = process_fus_daily(fus_df)

fus_df[100:150]
# Out:
# test
#      index       pid longitude latitude   timestamp       date prev_lat  \
# 100    100  61762096   17.4781  58.8655  1570777527 2019-10-11  58.8655
# 101    101  61762096   17.4781  58.8655  1570777832 2019-10-11  58.8655
# 102    102  61762096   17.4781  58.8655  1570778321 2019-10-11  58.8655
# 103    103  61762096   17.4781  58.8655  1570778651 2019-10-11  58.8655
# 104    104  61762096   17.4781  58.8655  1570779032 2019-10-11  58.8655
# 105    105  61762096   17.4781  58.8655  1570779420 2019-10-11  58.8655
# 106    106  61762096   17.4781  58.8655  1570779932 2019-10-11  58.8655
# 107    107  61762096   17.4781  58.8655  1570780232 2019-10-11  58.8655
# 108    108  61762096   17.4781  58.8655  1570780800 2019-10-11  58.8655
# 109    109  61762096   17.4781  58.8655  1570781127 2019-10-11  58.8655
# 110    110  61762096   17.4781  58.8655  1570781433 2019-10-11  58.8655
# 111    111  61762096   17.4781  58.8655  1570782027 2019-10-11  58.8655
# 112    112  61762096   17.4781  58.8655  1570782333 2019-10-11  58.8655
# 113    113  61762096   17.4781  58.8655  1570782633 2019-10-11  58.8655
# 114    114  61762096   17.4781  58.8655  1570782938 2019-10-11  58.8655
# 115    115  61762096   17.4781  58.8655  1570783533 2019-10-11  58.8655
# 116    116  61762096   17.4781  58.8655  1570783833 2019-10-11  58.8655
# 117    117  61762096   17.4781  58.8655  1570784400 2019-10-11  58.8655
# 118    118  61762096   17.4781  58.8655  1570784719 2019-10-11  58.8655
# 119    119  61762096   17.4781  58.8655  1570785138 2019-10-11  58.8655
# 120    120  61762096   17.4781  58.8655  1570785633 2019-10-11  58.8655
# 121    121  61762096   17.4781  58.8655  1570785960 2019-10-11  58.8655
# 122    122  61762096   17.4781  58.8655  1570786391 2019-10-11  58.8655
# 123    123  61762096   17.4781  58.8655  1570786833 2019-10-11  58.8655
# 124    124  61762096   17.4781  58.8655  1570787133 2019-10-11  58.8655
# 125    125  61762096   17.4781  58.8655  1570787463 2019-10-11  58.8655
# 126    126  61762096   17.4781  58.8655  1570788327 2019-10-11  58.8655
# 127    127  61762096  -83.2603  23.2985  1570687843 2019-10-10  58.8655
# 128    128  61762096  -83.2605  23.2985  1570688346 2019-10-10  23.2985
# 129    129  61762096  -83.2605  23.2985  1570688693 2019-10-10  23.2985
# 130    130  61762096  -83.2605  23.2985  1570689052 2019-10-10  23.2985
# 131    131  61762096  -83.2605  23.2985  1570689627 2019-10-10  23.2985
# 132    132  61762096  -83.2605  23.2985  1570793174 2019-10-11  23.2985
# 133    133  61762096  -83.2605  23.2985  1570793628 2019-10-11  23.2985
# 134    134  61762096  -83.2605  23.2985  1570794051 2019-10-11  23.2985
# 135    135  61762096  -83.2605  23.2985  1570794367 2019-10-11  23.2985
# 136    136  61762096  -83.2605  23.2985  1570794785 2019-10-11  23.2985
# 137    137  61762096  -83.2605  23.2985  1570795145 2019-10-11  23.2985
# 138    138  61762096   11.9291  54.5767  1570819543 2019-10-11  23.2985
# 139    139  61762096   11.9823  54.4077  1570819870 2019-10-11  54.5767
# 140    140  61762096   11.9133  54.6928  1570820233 2019-10-11  54.4077
# 141    141  61762096  -86.6653  36.1464  1570721306 2019-10-10  54.6928
# 142    142  61762096  -86.6653  36.1465  1570721667 2019-10-10  36.1464
# 143    143  61762096  -86.6653  36.1464  1570721978 2019-10-10  36.1465
# 144    144  61762096  -86.6653  36.1464  1570722456 2019-10-10  36.1464
# 145    145  61762096  -86.6653  36.1464  1570722786 2019-10-10  36.1464
# 146    146  61762096  -86.6653  36.1464  1570723106 2019-10-10  36.1464
# 147    147  61762096  -86.6653  36.1464  1570723406 2019-10-10  36.1464
# 148    148  61762096  -86.6653  36.1464  1570723883 2019-10-10  36.1464
# 149    149  61762096  -86.6653  36.1465  1570724256 2019-10-10  36.1464
#
#     prev_long         dist  prev_timestamp  delta_timestamp     velocity  \
# 100   17.4781     0.000000    1.570777e+09         0.165278     0.000000
# 101   17.4781     0.000000    1.570778e+09         0.084722     0.000000
# 102   17.4781     0.000000    1.570778e+09         0.135833     0.000000
# 103   17.4781     0.000000    1.570778e+09         0.091667     0.000000
# 104   17.4781     0.000000    1.570779e+09         0.105833     0.000000
# 105   17.4781     0.000000    1.570779e+09         0.107778     0.000000
# 106   17.4781     0.000000    1.570779e+09         0.142222     0.000000
# 107   17.4781     0.000000    1.570780e+09         0.083333     0.000000
# 108   17.4781     0.000000    1.570780e+09         0.157778     0.000000
# 109   17.4781     0.000000    1.570781e+09         0.090833     0.000000
# 110   17.4781     0.000000    1.570781e+09         0.085000     0.000000
# 111   17.4781     0.000000    1.570781e+09         0.165000     0.000000
# 112   17.4781     0.000000    1.570782e+09         0.085000     0.000000
# 113   17.4781     0.000000    1.570782e+09         0.083333     0.000000
# 114   17.4781     0.000000    1.570783e+09         0.084722     0.000000
# 115   17.4781     0.000000    1.570783e+09         0.165278     0.000000
# 116   17.4781     0.000000    1.570784e+09         0.083333     0.000000
# 117   17.4781     0.000000    1.570784e+09         0.157500     0.000000
# 118   17.4781     0.000000    1.570784e+09         0.088611     0.000000
# 119   17.4781     0.000000    1.570785e+09         0.116389     0.000000
# 120   17.4781     0.000000    1.570785e+09         0.137500     0.000000
# 121   17.4781     0.000000    1.570786e+09         0.090833     0.000000
# 122   17.4781     0.000000    1.570786e+09         0.119722     0.000000
# 123   17.4781     0.000000    1.570786e+09         0.122778     0.000000
# 124   17.4781     0.000000    1.570787e+09         0.083333     0.000000
# 125   17.4781     0.000000    1.570787e+09         0.091667     0.000000
# 126   17.4781     0.000000    1.570787e+09         0.240000     0.000000
# 127   17.4781  8397.297492    1.570788e+09       -27.912222  -300.846612
# 128  -83.2603     0.012414    1.570688e+09         0.139722     0.088847
# 129  -83.2605     0.000000    1.570688e+09         0.096389     0.000000
# 130  -83.2605     0.000000    1.570689e+09         0.099722     0.000000
# 131  -83.2605     0.000000    1.570689e+09         0.159722     0.000000
# 132  -83.2605     0.000000    1.570690e+09        28.763056     0.000000
# 133  -83.2605     0.000000    1.570793e+09         0.126111     0.000000
# 134  -83.2605     0.000000    1.570794e+09         0.117500     0.000000
# 135  -83.2605     0.000000    1.570794e+09         0.087778     0.000000
# 136  -83.2605     0.000000    1.570794e+09         0.116111     0.000000
# 137  -83.2605     0.000000    1.570795e+09         0.100000     0.000000
# 138  -83.2605  8238.251681    1.570795e+09         6.777222  1215.579394
# 139   11.9291    19.101072    1.570820e+09         0.090833   210.287031
# 140   11.9823    32.014815    1.570820e+09         0.100833   317.502302
# 141   11.9133  7303.941112    1.570820e+09       -27.479722  -265.793848
# 142  -86.6653     0.002972    1.570721e+09         0.100278     0.029634
# 143  -86.6653     0.004570    1.570722e+09         0.086389     0.052903
# 144  -86.6653     0.001019    1.570722e+09         0.132778     0.007672
# 145  -86.6653     0.002432    1.570722e+09         0.091667     0.026528
# 146  -86.6653     0.001097    1.570723e+09         0.088889     0.012345
# 147  -86.6653     0.000520    1.570723e+09         0.083333     0.006240
# 148  -86.6653     0.004145    1.570723e+09         0.132500     0.031287
# 149  -86.6653     0.005940    1.570724e+09         0.103611     0.057325
#
#      stationary
# 100        True
# 101        True
# 102        True
# 103        True
# 104        True
# 105        True
# 106        True
# 107        True
# 108        True
# 109        True
# 110        True
# 111        True
# 112        True
# 113        True
# 114        True
# 115        True
# 116        True
# 117        True
# 118        True
# 119        True
# 120        True
# 121        True
# 122        True
# 123        True
# 124        True
# 125        True
# 126        True
# 127        True
# 128        True
# 129        True
# 130        True
# 131        True
# 132        True
# 133        True
# 134        True
# 135        True
# 136        True
# 137        True
# 138       False
# 139       False
# 140       False
# 141        True
# 142        True
# 143        True
# 144        True
# 145        True
# 146        True
# 147        True
# 148        True
# 149        True

# %%
# %%time

fus_df = format_raw_fus(raw_fus)
#fus_df = fus_df[(fus_df['date'] <= '2019-10-11') & (fus_df['date'] >= '2019-10-09')]
#fus_df = fus_df.sort_values('timestamp')
test = process_fus_daily(fus_df)
# Out:
# test
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# CPU times: user 16.9 s, sys: 0 ns, total: 16.9 s
# Wall time: 16.9 s
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ## Fused Location Processing

# %%
def process_fus_daily(fus, cluster_radius=0.2):
    """Processes daily fused location features.
    
    Assumes date, pid columns are populated.

    This includes average velocity, number of stationary clusters, location entropy, and location variance.

    For reference, see https://github.com/sosata/MobileDepression/tree/master/features and 
    Saeb et al: The relationship between mobile phone location sensor data and depressive symptom severity

    Args:
        fus (pd.DataFrame): the fused location df with latitude, longitude, date, and pid columns

    """
    
    if fus.shape[0]  < 1:
        return None
    
    # get stationary locations
    fus['prev_lat'] = fus['latitude'].shift()
    fus['prev_long'] = fus['longitude'].shift()
    fus['dist'] = fus.apply(lambda x: haversine((x.latitude, x.longitude), (x.prev_lat, x.prev_long)), axis=1) # in km
    fus['prev_timestamp'] = fus['timestamp'].shift()
    fus['delta_timestamp'] = ((fus['timestamp'] - fus['prev_timestamp']) / (60 * 60)).astype(float) # change to hours
    fus['velocity'] = fus['dist'] / fus['delta_timestamp']
    fus = fus[fus['velocity'] >= 0] # drop rows with negative velocities
    fus['stationary'] = fus['velocity'] < 1 # filter locations that have a speed of greater than 1 km/hr
    fus_stationary = fus[fus['stationary']]
    
    #return fus, fus_stationary

    if fus_stationary.shape[0] < 1:
        return None
        
    # TODO should this be stationary or all locations?
    loc_var = np.log(fus_stationary['latitude'].var() + fus_stationary['longitude'].var())

    # assign clusters
    cur_mean = 1
    cur_clusters = 0
    while cur_mean > cluster_radius:
        cur_clusters += 1
        X = fus_stationary[['latitude', 'longitude']]
        kmeans = KMeans(n_clusters=cur_clusters, random_state=0).fit(X)
        labels = kmeans.labels_
        clusters = kmeans.cluster_centers_
        X = X.reset_index(drop=True)
        X['labels'] = labels
        X['center'] = X.apply(lambda x: clusters[int(x.labels)], axis=1)
        X['dist'] = X.apply(lambda x: haversine((x.latitude, x.longitude), x.center), axis=1)
        cur_mean = X['dist'].mean()
    
    # get daily entropy
    fus_stationary = fus_stationary.reset_index(drop=True)
    fus_stationary['cluster'] = X['labels']
    label_group = fus_stationary.groupby(['date', 'cluster'])['delta_timestamp'].sum().unstack()
    label_group = label_group.fillna(0)
    label_group['total'] = label_group.sum(axis=1)
    label_group = label_group.div(label_group['total'], axis=0)
    label_group['entropy'] = -(np.log(label_group) * label_group).sum(axis=1)
    label_group['norm_entropy'] = label_group['entropy'] / np.log(cur_clusters) # entropy normalized by number of location clusters
    label_group = label_group.reset_index()
    
    fus_combined = fus.groupby(['pid', 'date'], as_index=False)['dist'].sum()
    fus_combined = pd.merge(fus_combined, label_group[['date', 'entropy', 'norm_entropy']], on='date', how='outer')
    fus_combined['cluster'] = cur_clusters
    fus_combined['loc_var'] = loc_var
    
    fus_combined['velocity'] = fus.groupby(['pid', 'date'], as_index=False)['velocity'].mean()['velocity']
    #display(fus.groupby(['pid', 'date'], as_index=False)['velocity'].mean())
    #fus_moving = fus[fus['stationary'] > 0]
    
    #fus_combined['transition_time'] = fus_moving.groupby(['pid', 'date'], as_index=False)['delta_timestamp'].sum()
    #display(fus_moving.groupby(['pid', 'date'], as_index=False)['delta_timestamp'].sum())
    
    return fus_combined


def format_raw_fus(fus):
    """Formats raw fus df and returns one ready for processing.

    Args:
        fus (pd.DataFrame): raw fus df pulled from lifesense server

    Returns:
        pd.DataFrame: formatted fus DataFrame
    """    
    fus = format_time(fus)
    
    final_fus = fus
    final_fus['timestamp'] = final_fus['adj_ts']
    
    return final_fus[['pid', 'longitude', 'latitude', 'timestamp', 'date']]


def build_fus_helper(pid, wk, start_date, end_date):
    """Builds fused location features within the given window.
    

    Assumes that the start_date and end_date fall within the given week.
    
    
    Args:
        - pid (str): the participant id
        - wk (int): the study week to pull data from: 1, 4, 7, 10, 13, 16
        - start_date (str): start date, yyyy-mm-dd
        - end_date (str): end date, yyyy-mm-dd
        
    Returns:
        - stats_df (pd.DataFrame): frame with fused location statistics calculated for the given time window
    """
    
    loc = "/data/tliu/wk{}_ls_data/pdk-location/{}.df".format(wk, pid)
    fus_df = pd.read_pickle(loc)
    if fus_df.shape[0] < 1:
        return

    fus_df = format_raw_fus(fus_df)
    fus_df = fus_df[(fus_df['date'] >= start_date) & (fus_df['date'] <= end_date)]
    print(fus_df.shape)
    fus_df["is_wkday"] = (pd.to_datetime(fus_df['date']).dt.dayofweek < 5).astype(float)
    
    wkend_stats = process_fus_daily(fus_df[fus_df["is_wkday"] == 0].copy())
    wkday_stats = process_fus_daily(fus_df[fus_df["is_wkday"] == 1].copy())
    total_stats = process_fus_daily(fus_df.copy())
    
    dfs = []
    
    if wkend_stats is not None:
        wkend_stats = wkend_stats.set_index('pid')
        wkend_stats = wkend_stats.add_suffix("_wkend")
        dfs.append(wkend_stats.mean())
    
    if wkday_stats is not None:
        wkday_stats = wkday_stats.set_index('pid')
        wkday_stats = wkday_stats.add_suffix("_wkday")
        dfs.append(wkday_stats.mean())
    
    if total_stats is not None:
        total_stats = total_stats.set_index('pid')
        total_stats = total_stats.add_suffix("_total")
        dfs.append(total_stats.mean())
    
    stats_df = pd.DataFrame()
    if len(dfs) > 0:
        stats_df = pd.concat(dfs)
        stats_df = stats_df.to_frame().transpose()
        stats_df['pid'] = pid
        stats_df['study_wk'] = wk

    return stats_df

# %%
# %%time

pre_days = 14
post_days = -1
n_procs = 6

fun_args = []
for idx, row in shift_df.iterrows():
    date = row['date']
    pid = row['pid']
    wk = row['study_wk']
    
    start_date = date.floor('D') - pd.Timedelta(pre_days, unit='D')    
    end_date = date.floor('D') + pd.Timedelta(post_days, unit='D')
    
    fun_args.append((pid, wk, start_date, end_date))
   
with multiprocessing.Pool(n_procs) as pool:
    results = pool.starmap(build_fus_helper, fun_args)

df = pd.DataFrame()

for res in results:
    df = df.append(res)
# Out:
# (106, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2355, 5)
# (1930, 5)
# (1874, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2940, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (3052, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (891, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1010, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2181, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (3050, 5)
# (3072, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1849, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1167, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (3051, 5)
# (2862, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2965, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1353, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2910, 5)
# (1838, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2975, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2149, 5)
# (2043, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2926, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2808, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (738, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2346, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2941, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1067, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (1337, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2444, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2597, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (2284, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (0, 5)
# (2035, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2345, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (1090, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (1560, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# ...
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (3372, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (3101, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (3239, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (0, 5)
# (1207, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (3294, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (3130, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (3236, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2742, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (2479, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (3003, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log
# (356, 5)
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tliu/.conda/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# CPU times: user 8.32 s, sys: 1.42 s, total: 9.74 s
# Wall time: 23min 2s

# %%
#df.to_pickle("ls_data/shift_fus.df")

# %%
df[df['velocity_total'] > 10000].shape
# Out:
# (25, 20)

# %% [markdown]
# ### Notes
#
# - shift df needs:
#     - pid, phq_start, study_wk
# - Should standardization of features be per participant or global?
#     - likely global
#
# - fus correctness analysis:
#     - for the problematic frame (negative velocities), there seemed to be an issue with time zone corrections while flying, leading to timestamps "backwards" in time
#     - it appears that we can still approximate well the individual's distance traveled and velocity without the negative velocities, so the solution is to drop the negative velocity rows
